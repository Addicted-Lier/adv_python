# %%
def change(x):
    x = 100
    print(x)
    
a  = 10
change(a)
print(a)
# Out:
# 100
# 10

# %%
import copy
def add_item(x):
    x=copy.deepcopy(x)
    x.append(100)
    print(f"this is inside print = {x}")

nums = [1,2,3,4,5]
add_item(nums)
print(f"this is outside = {nums}")
# Out:
# this is inside print = [1, 2, 3, 4, 5, 100]
# this is outside = [1, 2, 3, 4, 5]
